# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
from src.paths import TRANSFORMED_DATA_DIR

df = pd.read_parquet(TRANSFORMED_DATA_DIR / 'validated_churn_data.parquet')
df
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0             1               1        101348.88       1
# 1             0               1        112542.58       0
# 2             1               0        113931.57       1
# 3             0               0         93826.63       0
# 4             1               1         79084.10       0
# ...         ...             ...              ...     ...
# 9995          1               0         96270.64       0
# 9996          1               1        101699.77       0
# 9997          0               1         42085.58       1
# 9998          1               0         92888.52       1
# 9999          1               0         38190.78       0
#
# [10000 rows x 11 columns]

# %%
from src.data_split import train_test_split_stratified

X_train, y_train, X_test, y_test = train_test_split_stratified(
    df,
    target_column_name='Exited'
)

print(f'{X_train.shape=}')
print(f'{y_train.shape=}')
print(f'{X_test.shape=}')
print(f'{y_test.shape=}')
# Out:
# X_train.shape=(8000, 10)
# y_train.shape=(8000,)
# X_test.shape=(2000, 10)
# y_test.shape=(2000,)

# %%
import numpy as np
from sklearn.model_selection import StratifiedKFold, train_test_split
# from sklearn.pipeline import make_pipeline
from sklearn.metrics import auc,accuracy_score,f1_score
import optuna


from src.data_split import train_test_split_stratified
from src.model import get_pipeline

def objective(trial: optuna.trial.Trial) -> float:
    """
    Given a set of hyper-parameters, it trains a model and computes an average
    validation error based on a train test split
    """
    # pick hyper-parameters
    hyperparams = {
        "objective": 'binary',
        "metric" : "f1_score",
        "verbose": -1,
        "num_leaves": trial.suggest_int("num_leaves", 2, 256),
        "feature_fraction": trial.suggest_float("feature_fraction", 0.2, 1.0),
        "bagging_fraction": trial.suggest_float("bagging_fraction", 0.2, 1.0),
        "min_child_samples": trial.suggest_int("min_child_samples", 3, 100),  
        "max_depth" : trial.suggest_int("max_depth", 3, 50)
    }
    

    skf = StratifiedKFold(n_splits=5)
    f1_scores_ = []
    for train_index, val_index in skf.split(X_train, y_train):

        # split data for training and validation
        X_train_, X_val_ = X_train.iloc[train_index, :], X_train.iloc[val_index,:]
        y_train_, y_val_ = y_train.iloc[train_index], y_train.iloc[val_index]
        
        # train the model
        pipeline = get_pipeline(**hyperparams)
        pipeline.fit(X_train_, y_train_)
        
        # evaluate the model
        y_pred = pipeline.predict(X_val_)
        f1_ = f1_score(y_val_, y_pred)

        f1_scores_.append(f1_)
   
    # Return the mean score
    return np.array(f1_scores_).mean()

# %%
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=50)
# Out:
# [I 2024-05-30 12:35:14,804] A new study created in memory with name: no-name-ad7011a5-6179-4608-91b0-fc0179d6a881
# [I 2024-05-30 12:35:16,114] Trial 0 finished with value: 0.569163202304188 and parameters: {'num_leaves': 108, 'feature_fraction': 0.5989685431256477, 'bagging_fraction': 0.5982248268556387, 'min_child_samples': 56, 'max_depth': 41}. Best is trial 0 with value: 0.569163202304188.
# [I 2024-05-30 12:35:16,633] Trial 1 finished with value: 0.5600002622975699 and parameters: {'num_leaves': 93, 'feature_fraction': 0.45484235339222523, 'bagging_fraction': 0.931853804620481, 'min_child_samples': 57, 'max_depth': 3}. Best is trial 0 with value: 0.569163202304188.
# [I 2024-05-30 12:35:18,336] Trial 2 finished with value: 0.5257522322355329 and parameters: {'num_leaves': 248, 'feature_fraction': 0.31143449504481624, 'bagging_fraction': 0.8823853321280797, 'min_child_samples': 31, 'max_depth': 26}. Best is trial 0 with value: 0.569163202304188.
# [I 2024-05-30 12:35:19,552] Trial 3 finished with value: 0.5786372524023927 and parameters: {'num_leaves': 222, 'feature_fraction': 0.9703796606941812, 'bagging_fraction': 0.7498931636914503, 'min_child_samples': 33, 'max_depth': 10}. Best is trial 3 with value: 0.5786372524023927.
# [I 2024-05-30 12:35:21,957] Trial 4 finished with value: 0.553480676553055 and parameters: {'num_leaves': 169, 'feature_fraction': 0.5889262425829431, 'bagging_fraction': 0.7635587503072834, 'min_child_samples': 14, 'max_depth': 27}. Best is trial 3 with value: 0.5786372524023927.
# [I 2024-05-30 12:35:23,001] Trial 5 finished with value: 0.5678644710351132 and parameters: {'num_leaves': 139, 'feature_fraction': 0.8857709730822332, 'bagging_fraction': 0.8897613762476657, 'min_child_samples': 94, 'max_depth': 26}. Best is trial 3 with value: 0.5786372524023927.
# [I 2024-05-30 12:35:23,961] Trial 6 finished with value: 0.5723037101663128 and parameters: {'num_leaves': 49, 'feature_fraction': 0.9690266939193664, 'bagging_fraction': 0.5117907038926559, 'min_child_samples': 7, 'max_depth': 21}. Best is trial 3 with value: 0.5786372524023927.
# [I 2024-05-30 12:35:27,163] Trial 7 finished with value: 0.5751025396234509 and parameters: {'num_leaves': 155, 'feature_fraction': 0.898778455506613, 'bagging_fraction': 0.26755839263140413, 'min_child_samples': 36, 'max_depth': 30}. Best is trial 3 with value: 0.5786372524023927.
# [I 2024-05-30 12:35:29,839] Trial 8 finished with value: 0.5692224481056132 and parameters: {'num_leaves': 160, 'feature_fraction': 0.9505686135091267, 'bagging_fraction': 0.8898157934784743, 'min_child_samples': 40, 'max_depth': 50}. Best is trial 3 with value: 0.5786372524023927.
# [I 2024-05-30 12:35:31,014] Trial 9 finished with value: 0.5702152077071032 and parameters: {'num_leaves': 213, 'feature_fraction': 0.5925892660710705, 'bagging_fraction': 0.9933762143413627, 'min_child_samples': 59, 'max_depth': 15}. Best is trial 3 with value: 0.5786372524023927.
# [I 2024-05-30 12:35:31,395] Trial 10 finished with value: 0.5492442596607102 and parameters: {'num_leaves': 4, 'feature_fraction': 0.7535234151240088, 'bagging_fraction': 0.42171738910340123, 'min_child_samples': 82, 'max_depth': 4}. Best is trial 3 with value: 0.5786372524023927.
# [I 2024-05-30 12:35:34,780] Trial 11 finished with value: 0.5653563903345247 and parameters: {'num_leaves': 207, 'feature_fraction': 0.7889200455375592, 'bagging_fraction': 0.2913553022746573, 'min_child_samples': 28, 'max_depth': 37}. Best is trial 3 with value: 0.5786372524023927.
# [I 2024-05-30 12:35:36,339] Trial 12 finished with value: 0.5669266047081768 and parameters: {'num_leaves': 255, 'feature_fraction': 0.8027826961439144, 'bagging_fraction': 0.7190343566270516, 'min_child_samples': 39, 'max_depth': 13}. Best is trial 3 with value: 0.5786372524023927.
# [I 2024-05-30 12:35:39,342] Trial 13 finished with value: 0.5566514274853024 and parameters: {'num_leaves': 196, 'feature_fraction': 0.9994071939930397, 'bagging_fraction': 0.40969653556470165, 'min_child_samples': 18, 'max_depth': 35}. Best is trial 3 with value: 0.5786372524023927.
# [I 2024-05-30 12:35:40,401] Trial 14 finished with value: 0.5805274914134941 and parameters: {'num_leaves': 175, 'feature_fraction': 0.7126032196874906, 'bagging_fraction': 0.7061810721971594, 'min_child_samples': 70, 'max_depth': 10}. Best is trial 14 with value: 0.5805274914134941.
# [I 2024-05-30 12:35:41,651] Trial 15 finished with value: 0.58041880082438 and parameters: {'num_leaves': 225, 'feature_fraction': 0.7245374303027932, 'bagging_fraction': 0.7262536023149688, 'min_child_samples': 70, 'max_depth': 13}. Best is trial 14 with value: 0.5805274914134941.
# [I 2024-05-30 12:35:42,695] Trial 16 finished with value: 0.5716453803926583 and parameters: {'num_leaves': 182, 'feature_fraction': 0.689197245339871, 'bagging_fraction': 0.6473872884309173, 'min_child_samples': 77, 'max_depth': 18}. Best is trial 14 with value: 0.5805274914134941.
# [I 2024-05-30 12:35:43,600] Trial 17 finished with value: 0.5405169120827548 and parameters: {'num_leaves': 119, 'feature_fraction': 0.43894334212710584, 'bagging_fraction': 0.6164013564173019, 'min_child_samples': 72, 'max_depth': 9}. Best is trial 14 with value: 0.5805274914134941.
# [I 2024-05-30 12:35:44,713] Trial 18 finished with value: 0.5634536958986469 and parameters: {'num_leaves': 226, 'feature_fraction': 0.47965752055596206, 'bagging_fraction': 0.7915408121318236, 'min_child_samples': 67, 'max_depth': 20}. Best is trial 14 with value: 0.5805274914134941.
# [I 2024-05-30 12:35:45,435] Trial 19 finished with value: 0.5833299690439314 and parameters: {'num_leaves': 78, 'feature_fraction': 0.6851338861055549, 'bagging_fraction': 0.530335433883925, 'min_child_samples': 100, 'max_depth': 8}. Best is trial 19 with value: 0.5833299690439314.
# [I 2024-05-30 12:35:46,201] Trial 20 finished with value: 0.5838020681872037 and parameters: {'num_leaves': 70, 'feature_fraction': 0.6627412441646062, 'bagging_fraction': 0.5105893676260749, 'min_child_samples': 91, 'max_depth': 8}. Best is trial 20 with value: 0.5838020681872037.
# [I 2024-05-30 12:35:46,917] Trial 21 finished with value: 0.578354757294031 and parameters: {'num_leaves': 72, 'feature_fraction': 0.6475350957323296, 'bagging_fraction': 0.49794819888668695, 'min_child_samples': 98, 'max_depth': 8}. Best is trial 20 with value: 0.5838020681872037.
# [I 2024-05-30 12:35:47,665] Trial 22 finished with value: 0.5687929010183843 and parameters: {'num_leaves': 49, 'feature_fraction': 0.8279745499568817, 'bagging_fraction': 0.5248822044975061, 'min_child_samples': 87, 'max_depth': 7}. Best is trial 20 with value: 0.5838020681872037.
# [I 2024-05-30 12:35:48,538] Trial 23 finished with value: 0.5714533828518353 and parameters: {'num_leaves': 83, 'feature_fraction': 0.5325206864621332, 'bagging_fraction': 0.38956960422243564, 'min_child_samples': 89, 'max_depth': 17}. Best is trial 20 with value: 0.5838020681872037.
# [I 2024-05-30 12:35:48,959] Trial 24 finished with value: 0.5609008870121233 and parameters: {'num_leaves': 56, 'feature_fraction': 0.6693394190954283, 'bagging_fraction': 0.574117892844252, 'min_child_samples': 100, 'max_depth': 3}. Best is trial 20 with value: 0.5838020681872037.
# [I 2024-05-30 12:35:49,509] Trial 25 finished with value: 0.561898068486727 and parameters: {'num_leaves': 20, 'feature_fraction': 0.35533864187274866, 'bagging_fraction': 0.6567105072101586, 'min_child_samples': 82, 'max_depth': 7}. Best is trial 20 with value: 0.5838020681872037.
# [I 2024-05-30 12:35:50,210] Trial 26 finished with value: 0.4976355233575876 and parameters: {'num_leaves': 136, 'feature_fraction': 0.2118593418871519, 'bagging_fraction': 0.3283881613980367, 'min_child_samples': 92, 'max_depth': 11}. Best is trial 20 with value: 0.5838020681872037.
# [I 2024-05-30 12:35:51,496] Trial 27 finished with value: 0.5649301619599971 and parameters: {'num_leaves': 108, 'feature_fraction': 0.5394442487802138, 'bagging_fraction': 0.45919466009791216, 'min_child_samples': 48, 'max_depth': 22}. Best is trial 20 with value: 0.5838020681872037.
# [I 2024-05-30 12:35:52,258] Trial 28 finished with value: 0.5770171198151341 and parameters: {'num_leaves': 35, 'feature_fraction': 0.6525051111475056, 'bagging_fraction': 0.5757528838032513, 'min_child_samples': 65, 'max_depth': 14}. Best is trial 20 with value: 0.5838020681872037.
# [I 2024-05-30 12:35:53,421] Trial 29 finished with value: 0.5767739674230271 and parameters: {'num_leaves': 74, 'feature_fraction': 0.7301254186936925, 'bagging_fraction': 0.685524916779953, 'min_child_samples': 79, 'max_depth': 45}. Best is trial 20 with value: 0.5838020681872037.
# [I 2024-05-30 12:35:54,012] Trial 30 finished with value: 0.5800492476139029 and parameters: {'num_leaves': 94, 'feature_fraction': 0.846526699207075, 'bagging_fraction': 0.552248194829521, 'min_child_samples': 49, 'max_depth': 6}. Best is trial 20 with value: 0.5838020681872037.
# [I 2024-05-30 12:35:54,996] Trial 31 finished with value: 0.5722703802602566 and parameters: {'num_leaves': 184, 'feature_fraction': 0.7358914447012102, 'bagging_fraction': 0.790637623016555, 'min_child_samples': 73, 'max_depth': 11}. Best is trial 20 with value: 0.5838020681872037.
# [I 2024-05-30 12:35:55,908] Trial 32 finished with value: 0.5743896082884129 and parameters: {'num_leaves': 240, 'feature_fraction': 0.7192623907902002, 'bagging_fraction': 0.6082178689912175, 'min_child_samples': 87, 'max_depth': 14}. Best is trial 20 with value: 0.5838020681872037.
# [I 2024-05-30 12:35:56,336] Trial 33 finished with value: 0.5715821015766654 and parameters: {'num_leaves': 107, 'feature_fraction': 0.6215906065275497, 'bagging_fraction': 0.700964045790026, 'min_child_samples': 65, 'max_depth': 4}. Best is trial 20 with value: 0.5838020681872037.
# [I 2024-05-30 12:35:57,399] Trial 34 finished with value: 0.5825108581279725 and parameters: {'num_leaves': 192, 'feature_fraction': 0.7716186286688739, 'bagging_fraction': 0.8364026481363427, 'min_child_samples': 58, 'max_depth': 11}. Best is trial 20 with value: 0.5838020681872037.
# [I 2024-05-30 12:35:58,791] Trial 35 finished with value: 0.5732623435812233 and parameters: {'num_leaves': 146, 'feature_fraction': 0.7779613500082343, 'bagging_fraction': 0.21137320246607938, 'min_child_samples': 54, 'max_depth': 17}. Best is trial 20 with value: 0.5838020681872037.
# [I 2024-05-30 12:35:59,816] Trial 36 finished with value: 0.5742030320956408 and parameters: {'num_leaves': 119, 'feature_fraction': 0.5426463739574782, 'bagging_fraction': 0.8273014739188825, 'min_child_samples': 61, 'max_depth': 11}. Best is trial 20 with value: 0.5838020681872037.
# [I 2024-05-30 12:36:00,386] Trial 37 finished with value: 0.5755112028642282 and parameters: {'num_leaves': 175, 'feature_fraction': 0.6793629954424586, 'bagging_fraction': 0.9672778906516512, 'min_child_samples': 96, 'max_depth': 6}. Best is trial 20 with value: 0.5838020681872037.
# [I 2024-05-30 12:36:01,443] Trial 38 finished with value: 0.579025188621945 and parameters: {'num_leaves': 62, 'feature_fraction': 0.8737864643071652, 'bagging_fraction': 0.8364825715001096, 'min_child_samples': 84, 'max_depth': 23}. Best is trial 20 with value: 0.5838020681872037.
# [I 2024-05-30 12:36:02,376] Trial 39 finished with value: 0.5780953986369488 and parameters: {'num_leaves': 195, 'feature_fraction': 0.6098543847719351, 'bagging_fraction': 0.4708534672260563, 'min_child_samples': 92, 'max_depth': 9}. Best is trial 20 with value: 0.5838020681872037.
# [I 2024-05-30 12:36:04,279] Trial 40 finished with value: 0.5717283819096741 and parameters: {'num_leaves': 163, 'feature_fraction': 0.9081821321627477, 'bagging_fraction': 0.9238801947641343, 'min_child_samples': 45, 'max_depth': 30}. Best is trial 20 with value: 0.5838020681872037.
# [I 2024-05-30 12:36:05,336] Trial 41 finished with value: 0.5807587390954156 and parameters: {'num_leaves': 229, 'feature_fraction': 0.7044640041908841, 'bagging_fraction': 0.7273896366917543, 'min_child_samples': 72, 'max_depth': 13}. Best is trial 20 with value: 0.5838020681872037.
# [I 2024-05-30 12:36:06,458] Trial 42 finished with value: 0.5769316750102469 and parameters: {'num_leaves': 240, 'feature_fraction': 0.6957297686222579, 'bagging_fraction': 0.85005792386594, 'min_child_samples': 76, 'max_depth': 11}. Best is trial 20 with value: 0.5838020681872037.
# [I 2024-05-30 12:36:07,035] Trial 43 finished with value: 0.5742522159725814 and parameters: {'num_leaves': 205, 'feature_fraction': 0.7616763427767178, 'bagging_fraction': 0.7795012312878054, 'min_child_samples': 57, 'max_depth': 5}. Best is trial 20 with value: 0.5838020681872037.
# [I 2024-05-30 12:36:08,166] Trial 44 finished with value: 0.5685951085951086 and parameters: {'num_leaves': 89, 'feature_fraction': 0.5679486986523011, 'bagging_fraction': 0.6486841479541028, 'min_child_samples': 60, 'max_depth': 16}. Best is trial 20 with value: 0.5838020681872037.
# [I 2024-05-30 12:36:08,890] Trial 45 finished with value: 0.5837432843450971 and parameters: {'num_leaves': 32, 'feature_fraction': 0.8117042139089098, 'bagging_fraction': 0.7432615794045306, 'min_child_samples': 93, 'max_depth': 13}. Best is trial 20 with value: 0.5838020681872037.
# [I 2024-05-30 12:36:09,713] Trial 46 finished with value: 0.57677680000272 and parameters: {'num_leaves': 33, 'feature_fraction': 0.793731078803616, 'bagging_fraction': 0.7396902562615651, 'min_child_samples': 94, 'max_depth': 19}. Best is trial 20 with value: 0.5838020681872037.
# [I 2024-05-30 12:36:10,100] Trial 47 finished with value: 0.5549532044808492 and parameters: {'num_leaves': 5, 'feature_fraction': 0.8459584326053036, 'bagging_fraction': 0.8766780707917472, 'min_child_samples': 99, 'max_depth': 24}. Best is trial 20 with value: 0.5838020681872037.
# [I 2024-05-30 12:36:10,946] Trial 48 finished with value: 0.570539401472376 and parameters: {'num_leaves': 35, 'feature_fraction': 0.9290299244161936, 'bagging_fraction': 0.7628953907320825, 'min_child_samples': 89, 'max_depth': 13}. Best is trial 20 with value: 0.5838020681872037.
# [I 2024-05-30 12:36:11,582] Trial 49 finished with value: 0.5811622237638818 and parameters: {'num_leaves': 19, 'feature_fraction': 0.8146102310123533, 'bagging_fraction': 0.5430359747641714, 'min_child_samples': 83, 'max_depth': 15}. Best is trial 20 with value: 0.5838020681872037.

# %%
best_params = study.best_trial.params
print(f'{best_params=}')
# Out:
# best_params={'num_leaves': 70, 'feature_fraction': 0.6627412441646062, 'bagging_fraction': 0.5105893676260749, 'min_child_samples': 91, 'max_depth': 8}

# %%
study.best_trial.value
# Out:
# 0.5838020681872037

# %%
pipeline = get_pipeline(**best_params)
pipeline.fit(X_train, y_train)
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.6627412441646062, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6627412441646062
# [LightGBM] [Warning] bagging_fraction is set=0.5105893676260749, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5105893676260749
# [LightGBM] [Warning] feature_fraction is set=0.6627412441646062, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6627412441646062
# [LightGBM] [Warning] bagging_fraction is set=0.5105893676260749, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5105893676260749
# [LightGBM] [Info] Number of positive: 1630, number of negative: 6370
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000657 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 855
# [LightGBM] [Info] Number of data points in the train set: 8000, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.203750 -> initscore=-1.363019
# [LightGBM] [Info] Start training from score -1.363019
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Pipeline(steps=[('customlabelencode', CustomLabelEncode()),
#                 ('lgbmclassifier',
#                  LGBMClassifier(bagging_fraction=0.5105893676260749,
#                                 feature_fraction=0.6627412441646062,
#                                 max_depth=8, min_child_samples=91,
#                                 num_leaves=70))])

# %%
predictions = pipeline.predict(X_test)
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.6627412441646062, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6627412441646062
# [LightGBM] [Warning] bagging_fraction is set=0.5105893676260749, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5105893676260749

# %%
from sklearn.metrics import accuracy_score,recall_score, f1_score

test_accuracy = accuracy_score(y_test, predictions)
test_recall = recall_score(y_test,predictions )
test_f1 =f1_score(y_test,predictions)
print(f'{test_accuracy=:.4f}')
print(f'{test_recall=:.4f}')
print(f'{test_f1=:.4f}')
# Out:
# test_accuracy=0.8710
# test_recall=0.5233
# test_f1=0.6228

# %%
import joblib
from src.paths import MODELS_DIR

joblib.dump(pipeline, MODELS_DIR / 'model.pkl')
# Out:
# ['C:\\Users\\karthikeya\\bank_customer_attrition_prediction\\models\\model.pkl']

# %%
X_test
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 9723          526    France    Male   32       7  125540.05              1
# 1809          639    France  Female   50       6  115335.32              2
# 456           733    France    Male   33       3       0.00              1
# 7458          728     Spain  Female   43       5       0.00              1
# 7403          796     Spain    Male   56       6   94231.13              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 7338          708   Germany  Female   54       8  145151.40              1
# 7095          753   Germany  Female   38       1  117314.92              1
# 1411          685   Germany  Female   30       4   84958.60              2
# 435           762    France  Female   51       3   99286.98              1
# 6518          521     Spain  Female   49       4   82940.25              2
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# 9723          0               0         86786.41
# 1809          1               1         53130.41
# 456           1               1          7666.73
# 7458          1               1        120088.17
# 7403          0               0        121164.60
# ...         ...             ...              ...
# 7338          0               1        125311.17
# 7095          1               0        122021.33
# 1411          0               1        194343.72
# 435           0               1         85578.63
# 6518          0               0         62413.01
#
# [2000 rows x 10 columns]
